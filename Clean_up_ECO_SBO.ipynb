# %% [markdown]
# ## Clean up model and add SBO and ECO Terms

# %% [markdown]
# ### Import and methods

# %%
import cobra
import pandas as pd
import libsbml

reader = libsbml.SBMLReader()
writer = libsbml.SBMLWriter()

model = cobra.io.read_sbml_model("2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.xml")

# %%
model.reactions.ATPM.annotation.update({"sbo": "SBO:0000176"})

# %% [markdown]
# ### SBO Terms

# %% [markdown]
# #### Reactions

# %%
for r in model.reactions:
    if "sbo" not in r.annotation:
        if r.id in model.exchanges or r.id.startswith("EX_"):
            r.annotation.update({"sbo": "SBO:0000627"})   # add exchange reactions
        elif not r.reactants:
            r.annotation.update({"sbo": "SBO:0000632"})   # add sink reactions
        elif not r.products:
            r.annotation.update({"sbo": "SBO:0000628"})   # add demand reactions
        else:
            bigg_ids = [m.id[:-2] for m in r.metabolites]
            if len(bigg_ids) > len(set(bigg_ids)):
                r.annotation.update({"sbo": "SBO:0000185"})   # add transport reactions
            else:
                r.annotation.update({"sbo": "SBO:0000176"})   # add metabolic reactions

# %% [markdown]
# #### Metabolites

# %%
for m in model.metabolites:
    if "sbo" not in m.annotation:
        m.annotation.update({"sbo": "SBO:0000247"})   # add metabolites

# %% [markdown]
# #### Genes

# %%
for g in model.genes:
    if "sbo" not in g.annotation:
        g.annotation.update({"sbo": "SBO:0000243"})   # add genes

# %%
cobra.io.write_sbml_model(model, "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.xml")

# %%
import memote
# Make memote report
result = memote.test_model(model, results=True)  #, skip=["test_find_metabolites_not_produced_with_open_bounds"])
report = memote.snapshot_report(result[1], config=None, html=True)
with open("2.2/memote-reports/report.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.html", "w") as handle:
    handle.write(report)
# Out:
# =============================================================================================== test session starts ===============================================================================================
# platform linux -- Python 3.8.8, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests
# plugins: anyio-3.3.0
# collected 145 items
#
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py ...FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.F.F......FF....FFFF.F.FF.FFF..                             [ 44%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py ......F........F.FFFFFF                                                                            [ 60%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py .F.....F.F                                                                                       [ 67%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py .ssssssssssssssssFFFFFFFFFF                                                                  [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_essentiality.py s                                                                                           [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_growth.py s                                                                                                 [ 87%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_matrix.py ....                                                                                              [ 90%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py FF                                                                                                  [ 91%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py FFFFFFFFsF.                                                                                          [ 99%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_thermodynamics.py .                                                                                         [100%]
#
# ==================================================================================================== FAILURES =====================================================================================================
# ______________________________________________________________________________ test_metabolite_annotation_overview[pubchem.compound] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for
# E     pubchem.compound:         10fthf_c, 12dag3p_BS_c, 12dgr120_c,
# E     12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# _______________________________________________________________________________ test_metabolite_annotation_overview[kegg.compound] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 359 metabolites (37.09%) lack annotation for
# E     kegg.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 359 == 0
# E    +  where 359 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _______________________________________________________________________________ test_metabolite_annotation_overview[seed.compound] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 248 metabolites (25.62%) lack annotation for
# E     seed.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 248 == 0
# E    +  where 248 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________________________________________________________________________ test_metabolite_annotation_overview[inchikey] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 295 metabolites (30.48%) lack annotation for inchikey:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 295 == 0
# E    +  where 295 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[inchi] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for inchi:
# E     10fthf_c, 12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[chebi] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 315 metabolites (32.54%) lack annotation for chebi:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 315 == 0
# E    +  where 315 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ____________________________________________________________________________________ test_metabolite_annotation_overview[hmdb] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 424 metabolites (43.80%) lack annotation for hmdb:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 424 == 0
# E    +  where 424 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________________________________________________________________________ test_metabolite_annotation_overview[reactome] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 589 metabolites (60.85%) lack annotation for reactome:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 589 == 0
# E    +  where 589 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _____________________________________________________________________________ test_metabolite_annotation_overview[metanetx.chemical] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 167 metabolites (17.25%) lack annotation for
# E     metanetx.chemical:         2mb_p_c, 2mba_c, 2mba_e, 2mpa_c, 2mpa_e,
# E     ...
# E   assert 167 == 0
# E    +  where 167 = len(['2mb_p_c', '2mba_c', '2mba_e', '2mpa_c', '2mpa_e', 'fe3pyovd_kt_e', ...])
# ______________________________________________________________________________ test_metabolite_annotation_overview[bigg.metabolite] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 147 metabolites (15.19%) lack annotation for
# E     bigg.metabolite:         aproa_c, id3acald_c, ind3ac_c, im4act_c,
# E     im4ac_c, ...
# E   assert 147 == 0
# E    +  where 147 = len(['aproa_c', 'id3acald_c', 'ind3ac_c', 'im4act_c', 'im4ac_c', 'imzacd_c', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[biocyc] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 301 metabolites (31.10%) lack annotation for biocyc:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 301 == 0
# E    +  where 301 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _____________________________________________________________________________________ test_reaction_annotation_overview[rhea] _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 744 reactions (56.49%) lack annotation for rhea:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 744 == 0
# E    +  where 744 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[kegg.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 843 reactions (64.01%) lack annotation for
# E     kegg.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 843 == 0
# E    +  where 843 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[seed.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 450 reactions (34.17%) lack annotation for
# E     seed.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 450 == 0
# E    +  where 450 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ______________________________________________________________________________ test_reaction_annotation_overview[metanetx.reaction] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 224 reactions (17.01%) lack annotation for
# E     metanetx.reaction:         13PPDH2, 2AACLPPEAT160, 2MBAt6, 2MPAt6,
# E     2OBUT_Et, ...
# E   assert 224 == 0
# E    +  where 224 = len(['13PPDH2', '2AACLPPEAT160', '2MBAt6', '2MPAt6', '2OBUT_Et', '4HBAt', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[bigg.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 134 reactions (10.17%) lack annotation for
# E     bigg.reaction:         AGPATr_BS, ALATA_D, ALATA_D2, ALATA_L2,
# E     ALCD22_L, ...
# E   assert 134 == 0
# E    +  where 134 = len(['AGPATr_BS', 'ALATA_D', 'ALATA_D2', 'ALATA_L2', 'ALCD22_L', 'CYSK2_I', ...])
# ___________________________________________________________________________________ test_reaction_annotation_overview[reactome] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1132 reactions (85.95%) lack annotation for reactome:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1132 == 0
# E    +  where 1132 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ___________________________________________________________________________________ test_reaction_annotation_overview[ec-code] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 620 reactions (47.08%) lack annotation for ec-code:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 620 == 0
# E    +  where 620 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ____________________________________________________________________________________ test_reaction_annotation_overview[brenda] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1317 reactions (100.00%) lack annotation for brenda:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1317 == 0
# E    +  where 1317 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ____________________________________________________________________________________ test_reaction_annotation_overview[biocyc] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 730 reactions (55.43%) lack annotation for biocyc:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 730 == 0
# E    +  where 730 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# __________________________________________________________________________________ test_gene_product_annotation_overview[refseq] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for refseq:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[uniprot] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for uniprot:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[ecogene] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ecogene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ________________________________________________________________________________ test_gene_product_annotation_overview[kegg.genes] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for kegg.genes:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# __________________________________________________________________________________ test_gene_product_annotation_overview[ncbigi] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigi:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[ncbigene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _______________________________________________________________________________ test_gene_product_annotation_overview[ncbiprotein] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for ncbiprotein:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[ccds] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ccds:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[hprd] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for hprd:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[asap] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for asap:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _____________________________________________________________________________ test_metabolite_annotation_wrong_ids[pubchem.compound] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the pubchem.compound database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _______________________________________________________________________________ test_metabolite_annotation_wrong_ids[seed.compound] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:292: in test_metabolite_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 1 metabolite annotations (0.14%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     seed.compound         database: trdox_c
# E   assert 1 == 0
# E    +  where 1 = len(['trdox_c'])
# ___________________________________________________________________________________ test_metabolite_annotation_wrong_ids[inchi] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the inchi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ____________________________________________________________________________________ test_reaction_annotation_wrong_ids[rhea] _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 59 reaction annotations (4.48%) do not match the
# E     regular expression patterns defined on identifiers.org for the rhea
# E     database: AEPabcpp, ARGabc, ASPabc, ASPabcpp, CA2abc, ...
# E   assert 59 == 0
# E    +  where 59 = len(['AEPabcpp', 'ARGabc', 'ASPabc', 'ASPabcpp', 'CA2abc', 'CA2abc1', ...])
# ________________________________________________________________________________ test_reaction_annotation_wrong_ids[kegg.reaction] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 12 reaction annotations (0.91%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     kegg.reaction         database: AMALT1, AMALT2, AMALT3, HCO3E, LACZpp,
# E     ...
# E   assert 12 == 0
# E    +  where 12 = len(['AMALT1', 'AMALT2', 'AMALT3', 'HCO3E', 'LACZpp', 'MAL6PG', ...])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[ec-code] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 77 reaction annotations (5.85%) do not match the
# E     regular expression patterns defined on identifiers.org for the ec-code
# E     database: 4ABUTD, 4HTHRS, AKGDH, AKGt2r, ALCD4, ...
# E   assert 77 == 0
# E    +  where 77 = len(['4ABUTD', '4HTHRS', 'AKGDH', 'AKGt2r', 'ALCD4', 'ALCD4y', ...])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[brenda] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:328: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the brenda database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[biocyc] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 5 reaction annotations (0.38%) do not match the
# E     regular expression patterns defined on identifiers.org for the biocyc
# E     database: PHETYRr, TYRALAr, TYRGLUr, TYRTHRr, GLYTYRAP
# E   assert 5 == 0
# E    +  where 5 = len(['PHETYRr', 'TYRALAr', 'TYRGLUr', 'TYRTHRr', 'GLYTYRAP'])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[refseq] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:386: in test_gene_product_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 591 gene annotations (98.34%) do not match the
# E     regular expression patterns defined on identifiers.org for the refseq
# E     database: WP_012290939_1, WP_012290272_1, WP_002842355_1,
# E     WP_012291190_1, WP_012290992_1, ...
# E   assert 591 == 0
# E    +  where 591 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ecogene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ecogene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ncbigi] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ncbigene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ccds] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ccds database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[hprd] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the hprd database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[asap] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the asap database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ____________________________________________________________________________________ test_gene_protein_reaction_rule_presence _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:206: in test_gene_protein_reaction_rule_presence
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are a total of 305 reactions (23.16%) without GPR:
# E     MDDCP2pp, GLYC3Ptex, FAO11, 2AGPE160tipp, 2AGPEAT180, ...
# E   assert 305 == 0
# E    +  where 305 = len(['MDDCP2pp', 'GLYC3Ptex', 'FAO11', '2AGPE160tipp', '2AGPEAT180', 'LCTSt3ipp', ...])
# ______________________________________________________________________________________ test_transport_reaction_gpr_presence _______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:499: in test_transport_reaction_gpr_presence
#     assert ann["metric"] < 0.2, ann["message"]
# E   AssertionError: There are a total of 106 transport reactions (31.27% of all
# E     transport reactions) without GPR:         2AGPE160tipp, ADEtex,
# E     DDCAt2pp, 2AGPE161tipp, 12DGR161tipp, ...
# E   assert 0.31268436578171094 < 0.2
# __________________________________________________________________________________________ test_find_unique_metabolites ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:555: in test_find_unique_metabolites
#     assert len(ann["data"]) < len(model.metabolites), ann["message"]
# E   AssertionError: Not counting the same entities in other compartments, there is a
# E     total of 968 (100.00%) unique metabolites in the model: dad_2_c,
# E     drib_c, dpcoa_e, 5mtr_c, gthrd_e, ...
# E   assert 968 < 968
# E    +  where 968 = len(['dad_2_c', 'drib_c', 'dpcoa_e', '5mtr_c', 'gthrd_e', 'glcn_c', ...])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.metabolites
# _________________________________________________________________________________ test_find_duplicate_metabolites_in_compartments _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:584: in test_find_duplicate_metabolites_in_compartments
#     len(ann["data"]), truncate(ann["data"])))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:170: in truncate
#     return ", ".join(sequence)
# E   TypeError: sequence item 0: expected str instance, tuple found
# ____________________________________________________________________________ test_find_reactions_with_partially_identical_annotations _____________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:624: in test_find_reactions_with_partially_identical_annotations
#     assert total == 0, ann["message"]
# E   AssertionError: Based on annotations there are 137 different groups of overlapping
# E     annotation which corresponds to a total of 312 duplicated reactions in
# E     the model.
# E   assert 312 == 0
# __________________________________________________________________________________________ test_find_duplicate_reactions __________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:660: in test_find_duplicate_reactions
#     {}""".format(num, truncate(duplicates)))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:168: in truncate
#     return ", ".join(sequence[:LIST_SLICE] + ["..."])
# E   TypeError: sequence item 0: expected str instance, tuple found
# ____________________________________________________________________________________ test_find_reactions_with_identical_genes _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:692: in test_find_reactions_with_identical_genes
#     assert num_dup == 0, ann["message"]
# E   AssertionError: Based only on equal genes there are 154 different groups of
# E     identical reactions which corresponds to a total of 601
# E     duplicated reactions in the model.
# E   assert 601 == 0
# __________________________________________________________________________________________ test_find_medium_metabolites ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:713: in test_find_medium_metabolites
#     ann["metric"] = len(ann["data"]) / num_ex
# E   TypeError: unsupported operand type(s) for /: 'int' and 'list'
# ________________________________________________________________________________________ test_biomass_consistency[Growth] _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:121: in test_biomass_consistency
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: The component molar mass of the biomass reaction Growth sums up to
# E     1.0300277967729958             which is outside of the 1e-03 margin
# E     from 1 mmol / g[CDW] / h.
# E   assert False
# ________________________________________________________________________________________ test_fast_growth_default[Growth] _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:370: in test_fast_growth_default
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction Growth and when the model is simulated on
# E     the provided default medium the growth rate is *lower* than that
# E     of the fastest bacteria. This is to be expected for             a
# E     majority of organisms.
# E   assert False
# ________________________________________________________________________________ test_essential_precursors_not_in_biomass[Growth] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:494: in test_essential_precursors_not_in_biomass
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: Growth lacks a total of 1 essential metabolites         (1.72% of all
# E     biomass precursors). Specifically         these are: ['fmn_c'].
# E   assert 1 == 0
# E    +  where 1 = len(['fmn_c'])
# __________________________________________________________________________________________ test_reaction_charge_balance ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:158: in test_reaction_charge_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 3 (0.26%) reactions are charge unbalanced with at
# E     least one of the metabolites not having a charge or the overall
# E     charge not equal to 0: BTS2, AGPATr_BS, G3POA_BS
# E   assert 3 == 0
# E    +  where 3 = len(['BTS2', 'AGPATr_BS', 'G3POA_BS'])
# ___________________________________________________________________________________________ test_reaction_mass_balance ____________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:193: in test_reaction_mass_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 2 (0.17%) reactions are mass unbalanced with at least
# E     one of the metabolites not having a formula or the overall mass not
# E     equal to 0: AGPATr_BS, G3POA_BS
# E   assert 2 == 0
# E    +  where 2 = len(['AGPATr_BS', 'G3POA_BS'])
# _____________________________________________________________________________________________ test_blocked_reactions ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:222: in test_blocked_reactions
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 98 (7.44%) blocked reactions in         the model: EX_btn_e,
# E     EX_chol_e, EX_rmn_e, EX_spmd_e, EX_xyl__D_e, ...
# E   assert 98 == 0
# E    +  where 98 = len(['EX_btn_e', 'EX_chol_e', 'EX_rmn_e', 'EX_spmd_e', 'EX_xyl__D_e', 'ALDD22x', ...])
# __________________________________________________________________________________ test_find_stoichiometrically_balanced_cycles ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:246: in test_find_stoichiometrically_balanced_cycles
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 111 (8.43%) reactions         which participate in SBC in
# E     the model: 13PPDH, 13PPDH2, 4ABUTD, ABUTD, ACCOAL, ...
# E   assert 111 == 0
# E    +  where 111 = len(['13PPDH', '13PPDH2', '4ABUTD', 'ABUTD', 'ACCOAL', 'ACKr', ...])
# ________________________________________________________________________________________________ test_find_orphans ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:271: in test_find_orphans
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 42 (4.34%) metabolites are not produced by any reaction
# E     of the model: cl_p, inost_c, aproa_c, id3acald_c, im4act_c, ...
# E   assert 42 == 0
# E    +  where 42 = len(['cl_p', 'inost_c', 'aproa_c', 'id3acald_c', 'im4act_c', 'imzacd_c', ...])
# _______________________________________________________________________________________________ test_find_deadends ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:295: in test_find_deadends
#     assert ann["data"] == 0, ann["message"]
# E   AssertionError: A total of 45 (4.65%) metabolites are not consumed by any reaction
# E     of the model: 2ins_c, spmd_c, ind3ac_c, im4ac_c, imzac_c, ...
# E   assert ['2ins_c', 'spmd_c', 'ind3ac_c', 'im4ac_c', 'imzac_c', '4aabutn_c', ...] == 0
# _____________________________________________________________________________________________ test_find_disconnected ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:319: in test_find_disconnected
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 5 (0.52%) metabolites are not associated with any
# E     reaction of the model: 3php_c, pa160140_c, pa160180_c, pa160205n3_c,
# E     pa160226n3_c
# E   assert 5 == 0
# E    +  where 5 = len(['3php_c', 'pa160140_c', 'pa160180_c', 'pa160205n3_c', 'pa160226n3_c'])
# _______________________________________________________________________________ test_find_metabolites_not_produced_with_open_bounds _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:349: in test_find_metabolites_not_produced_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 250 (25.83%) metabolites cannot be produced in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 250 == 0
# E    +  where 250 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# _______________________________________________________________________________ test_find_metabolites_not_consumed_with_open_bounds _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:379: in test_find_metabolites_not_consumed_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 255 (26.34%) metabolites cannot be consumed in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 255 == 0
# E    +  where 255 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# ______________________________________________________________________________ test_find_reactions_unbounded_flux_default_condition _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:413: in test_find_reactions_unbounded_flux_default_condition
#     assert ann["metric"] <= 0.1, ann["message"]
# E   AssertionError:  A fraction of 22.32% of the non-blocked reactions (in total 98
# E     reactions) can carry unbounded flux in the default model
# E     condition. Unbounded reactions may be involved in
# E     thermodynamically infeasible cycles: 13PPDH, 13PPDH2, 4ABUTD, ABUTD,
# E     ACCOAL, ...
# E   assert 0.22323462414578588 <= 0.1
# _________________________________________________________________________________________________ test_sbml_level _________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:39: in test_sbml_level
#     sbml_version[0], sbml_version[1])
# E   TypeError: 'NoneType' object is not subscriptable
# ________________________________________________________________________________________________ test_fbc_presence ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:66: in test_fbc_presence
#     fbc_present = sbml_version[2] is not None
# E   TypeError: 'NoneType' object is not subscriptable
# __________________________________________________________________________________________ test_metabolite_sbo_presence ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:58: in test_metabolite_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.metabolites
# ___________________________________________________________________________________________ test_reaction_sbo_presence ____________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:88: in test_reaction_sbo_presence
#     assert len(ann["data"]) == len(model.reactions), ann["message"]
# E   AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 1317
# E    +  where 0 = len([])
# E    +  and   1317 = len([<Reaction 12DGR120tipp at 0x7ff063c92a60>, <Reaction 12DGR140tipp at 0x7ff063ba0ca0>, <Reaction 12DGR160tipp at 0x7ff...ff062fdef10>, <Reaction KAS8 at 0x7ff062fded30>, <Reaction NNDPR at 0x7ff062fdefd0>, <Reaction PPND at 0x7ff062f7af40>])
# E    +    where [<Reaction 12DGR120tipp at 0x7ff063c92a60>, <Reaction 12DGR140tipp at 0x7ff063ba0ca0>, <Reaction 12DGR160tipp at 0x7ff...ff062fdef10>, <Reaction KAS8 at 0x7ff062fded30>, <Reaction NNDPR at 0x7ff062fdefd0>, <Reaction PPND at 0x7ff062f7af40>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.reactions
# _____________________________________________________________________________________________ test_gene_sbo_presence ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:117: in test_gene_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# E     SBO term:
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7ff063c929a0>, <Gene WP_012290272_1 at 0x7ff063c92a00>, <Gene WP_002842355_1 at 0x7ff063c92...7ff063ba01c0>, <Gene FMG_0827 at 0x7ff063ba0b80>, <Gene FMG_1032 at 0x7ff063ba0b50>, <Gene FMG_0500 at 0x7ff063ba0c70>])
# E    +    where [<Gene WP_012290939_1 at 0x7ff063c929a0>, <Gene WP_012290272_1 at 0x7ff063c92a00>, <Gene WP_002842355_1 at 0x7ff063c92...7ff063ba01c0>, <Gene FMG_0827 at 0x7ff063ba0b80>, <Gene FMG_1032 at 0x7ff063ba0b50>, <Gene FMG_0500 at 0x7ff063ba0c70>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.genes
# __________________________________________________________________________________ test_metabolic_reaction_specific_sbo_presence __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:150: in test_metabolic_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(pure), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all purely
# E     metabolic reactions) lack annotation with the SBO term
# E     "SBO:0000176" for 'biochemical reaction':
# E   assert 0 == 818
# E    +  where 0 = len([])
# E    +  and   818 = len({<Reaction DCMPDA at 0x7ff0638f0070>, <Reaction 2AGPEAT180 at 0x7ff063b50130>, <Reaction NAMNPP at 0x7ff063038160>, <Reaction G1PP at 0x7ff06381fd30>, <Reaction ACKr at 0x7ff063b50220>, <Reaction DAGK140 at 0x7ff063958220>, ...})
# __________________________________________________________________________________ test_transport_reaction_specific_sbo_presence __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:188: in test_transport_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(transports), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# E     reactions) lack annotation with one of the SBO terms: ['SBO:0000185',
# E     'SBO:0000588', 'SBO:0000587', 'SBO:0000655', 'SBO:0000654',
# E     'SBO:0000660', 'SBO:0000659', 'SBO:0000657', 'SBO:0000658'] for
# E     'biochemical reaction':
# E   assert 0 == 339
# E    +  where 0 = len([])
# E    +  and   339 = len({<Reaction PTRCORNt7 at 0x7ff063328040>, <Reaction 2AGPE160tipp at 0x7ff063b500a0>, <Reaction ADEtex at 0x7ff063b50640>, <Reaction BTNt at 0x7ff0639e8790>, <Reaction ASPabcpp at 0x7ff0639e8850>, <Reaction PTRCabc at 0x7ff063328910>, ...})
# ______________________________________________________________________________________ test_metabolite_specific_sbo_presence ______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:218: in test_metabolite_specific_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# E     lack annotation with the SBO term "SBO:0000247" for
# E     'simple chemical':
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff064190820>, <Metabolite 12dag3p_BS_c at 0x7ff0641906a0>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff063cc1fa0>, <Metabolite tyrthr_c at 0x7ff063cc1fd0>, <Metabolite gly_tyr_c at 0x7ff063cc1f10>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.metabolites
# _________________________________________________________________________________________ test_gene_specific_sbo_presence _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:248: in test_gene_specific_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all genes) lack             annotation
# E     with the SBO term "SBO:0000243" for             'gene':
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7ff063c929a0>, <Gene WP_012290272_1 at 0x7ff063c92a00>, <Gene WP_002842355_1 at 0x7ff063c92...7ff063ba01c0>, <Gene FMG_0827 at 0x7ff063ba0b80>, <Gene FMG_1032 at 0x7ff063ba0b50>, <Gene FMG_0500 at 0x7ff063ba0c70>])
# E    +    where [<Gene WP_012290939_1 at 0x7ff063c929a0>, <Gene WP_012290272_1 at 0x7ff063c92a00>, <Gene WP_002842355_1 at 0x7ff063c92...7ff063ba01c0>, <Gene FMG_0827 at 0x7ff063ba0b80>, <Gene FMG_1032 at 0x7ff063ba0b50>, <Gene FMG_0500 at 0x7ff063ba0c70>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff064169520>.genes
# _______________________________________________________________________________________ test_exchange_specific_sbo_presence _______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:290: in test_exchange_specific_sbo_presence
#     assert len(ann["data"]) == len(exchanges), ann["message"]
# E   AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# E     reactions) lack annotation with the SBO term "SBO:0000627" for
# E     'exchange reaction':
# E   assert 0 == 157
# E    +  where 0 = len([])
# E    +  and   157 = len([<Reaction EX_14glucan_e at 0x7ff063175310>, <Reaction EX_15dap_e at 0x7ff0631acbe0>, <Reaction EX_26dap__M_e at 0x7ff...Reaction EX_atp_e at 0x7ff063001d90>, <Reaction EX_pan4p_e at 0x7ff063001f40>, <Reaction EX_dpcoa_e at 0x7ff063001eb0>])
# _________________________________________________________________________________________ test_sink_specific_sbo_presence _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:376: in test_sink_specific_sbo_presence
#     assert len(ann["data"]) == len(sinks), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# E     annotation with the SBO term "SBO:0000632" for         'sink
# E     reaction':
# E   assert 0 == 2
# E    +  where 0 = len([])
# E    +  and   2 = len([<Reaction sink_lipopb_c at 0x7ff0631db9a0>, <Reaction sink_mobd_c at 0x7ff063175580>])
# ================================================================================================ warnings summary =================================================================================================
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/support/thermodynamics.py:23
#   /home/salatan/anaconda3/lib/python3.8/site-packages/memote/support/thermodynamics.py:23: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#     from collections import Iterable, defaultdict
#
# -- Docs: https://docs.pytest.org/en/latest/warnings.html
# ========================================================================== 77 failed, 49 passed, 19 skipped, 1 warnings in 23.33 seconds ==========================================================================

# %% [markdown]
# ### ECO-Terms

# %%
def add_eco_annotation(model, lnk, s_id, element):  
    c = libsbml.CVTerm()
    c.setQualifierType(libsbml.BIOLOGICAL_QUALIFIER)
    c.setBiologicalQualifierType(libsbml.BQB_IS_DESCRIBED_BY)
    c.addResource(lnk)

    if element == "species":
        list_cv = [model.getSpecies(s_id).getCVTerm(i) for i in range(model.getSpecies(s_id).getNumCVTerms())]
        if not c in list_cv:     # eliminate duplicates
            model.getSpecies(s_id).addCVTerm(c)
            
    elif element == "reaction":
        list_cv = [model.getReaction(s_id).getCVTerm(i) for i in range(model.getReaction(s_id).getNumCVTerms())]
        if not c in list_cv:
            model.getReaction(s_id).addCVTerm(c)
            
    elif element == "gene":
        list_cv = [model.getPlugin("fbc").getGeneProduct(s_id).getCVTerm(i) for i in range(model.getPlugin("fbc").getGeneProduct(s_id).getNumCVTerms())]
        if not c in list_cv:
            model.getPlugin("fbc").getGeneProduct(s_id).addCVTerm(c)
    
    return model

# %%
doc = reader.readSBML("2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.xml")
model = doc.getModel()

# %%
manually_curated = pd.read_csv("2.2/tables/manually_curated_all.tsv", sep="\t",header=None)
manually_curated = list(manually_curated[0])

# %%
blast_evidence = ["THRD_L_1","BZDIOLDH"]

# %%
model_draft = cobra.io.read_sbml_model("2.2/finegoldia_magna_ATCC_29328_2.2.xml")
print(len(model_draft.reactions))
# Out:
# 1166

# %%
model_bgf = cobra.io.read_sbml_model("2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.xml")
model_gf = cobra.io.read_sbml_model("2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.xml")

reac_ids_bgf = [r.id for r in model_bgf.reactions]
reac_ids_gf = [r.id for r in model_gf.reactions]
added_automated_gf = list(set(reac_ids_gf) - set(reac_ids_bgf))
print(added_automated_gf)
# Out:
# ['NNDPR', 'DAPDC', 'KAS13', 'KARA2', 'DHAD2', 'KAS8', 'KAS7', 'ASPO2', 'ACHBS', 'BZ12DOX', 'PPND']

# %%
from tqdm import tqdm
for i in tqdm(range(model.getNumSpecies())):
    s_id = model.getSpecies(i).getId()
    if s_id in manually_curated:
        lnk = "https://identifiers.org/ECO:0007759"
    elif s_id in blast_evidence:
        lnk = "https://identifiers.org/ECO:0000031"
    elif s_id in model_draft.metabolites:
        lnk = "https://identifiers.org/ECO:0007482" # biological system reconstruction evidence based on homology evidence used in automatic assertion
    elif s_id in added_automated_gf:
        lnk = "https://identifiers.org/ECO:0000363" # computational inference used in automatic assertion
    else:
        lnk = "https://identifiers.org/ECO:0007636"
    model = add_eco_annotation(model, lnk, s_id, "species")
    
for i in tqdm(range(model.getNumReactions())):
    s_id = model.getReaction(i).getId()
    if s_id in manually_curated:
        lnk = "https://identifiers.org/ECO:0007759"
    elif s_id in blast_evidence:
        lnk = "https://identifiers.org/ECO:0000031"
    elif s_id in model_draft.reactions:
        lnk = "https://identifiers.org/ECO:0007482"
    elif s_id in added_automated_gf:
        lnk = "https://identifiers.org/ECO:0000363"
    else:
        lnk = "https://identifiers.org/ECO:0007636"
    model = add_eco_annotation(model, lnk, s_id, "reaction")
        
for i in tqdm(range(model.getPlugin("fbc").getNumGeneProducts())):
    s_id = model.getPlugin("fbc").getGeneProduct(i).getId()
    if s_id in manually_curated:
        lnk = "https://identifiers.org/ECO:0007759"
    elif s_id in blast_evidence:
        lnk = "https://identifiers.org/ECO:0000031"
    elif s_id in model_draft.genes:
        lnk = "https://identifiers.org/ECO:0007482"
    elif s_id in added_automated_gf:
        lnk = "https://identifiers.org/ECO:0000363"
    else:
        lnk = "https://identifiers.org/ECO:0007636"
    model = add_eco_annotation(model, lnk, s_id, "gene")
# Out:
# 100%|██████████| 968/968 [00:00<00:00, 17702.42it/s]
# 100%|██████████| 1317/1317 [00:00<00:00, 13802.40it/s]
# 100%|██████████| 601/601 [00:00<00:00, 14282.59it/s]

# %%
# Saving new model
doc.setModel(model)
writer.writeSBML(doc, "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.xml")
# Out:
# True

# %%
model = cobra.io.read_sbml_model("2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.xml")
# Make memote report
result = memote.test_model(model, results=True)  #, skip=["test_find_metabolites_not_produced_with_open_bounds"])
report = memote.snapshot_report(result[1], config=None, html=True)
with open("2.2/memote-reports/report.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.html", "w") as handle:
    handle.write(report)
# Out:
# =============================================================================================== test session starts ===============================================================================================
# platform linux -- Python 3.8.8, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests
# plugins: anyio-3.3.0
# collected 145 items
#
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py ...FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.F.F......FF....FFFF.F.FF.FFF..                             [ 44%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py ......F........F.FFFFFF                                                                            [ 60%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py .F.....F.F                                                                                       [ 67%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py .ssssssssssssssssFFFFFFFFFF                                                                  [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_essentiality.py s                                                                                           [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_growth.py s                                                                                                 [ 87%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_matrix.py ....                                                                                              [ 90%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py FF                                                                                                  [ 91%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py FFFFFFFFsF.                                                                                          [ 99%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_thermodynamics.py .                                                                                         [100%]
#
# ==================================================================================================== FAILURES =====================================================================================================
# ______________________________________________________________________________ test_metabolite_annotation_overview[pubchem.compound] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for
# E     pubchem.compound:         10fthf_c, 12dag3p_BS_c, 12dgr120_c,
# E     12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# _______________________________________________________________________________ test_metabolite_annotation_overview[kegg.compound] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 359 metabolites (37.09%) lack annotation for
# E     kegg.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 359 == 0
# E    +  where 359 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _______________________________________________________________________________ test_metabolite_annotation_overview[seed.compound] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 248 metabolites (25.62%) lack annotation for
# E     seed.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 248 == 0
# E    +  where 248 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________________________________________________________________________ test_metabolite_annotation_overview[inchikey] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 295 metabolites (30.48%) lack annotation for inchikey:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 295 == 0
# E    +  where 295 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[inchi] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for inchi:
# E     10fthf_c, 12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[chebi] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 315 metabolites (32.54%) lack annotation for chebi:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 315 == 0
# E    +  where 315 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ____________________________________________________________________________________ test_metabolite_annotation_overview[hmdb] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 424 metabolites (43.80%) lack annotation for hmdb:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 424 == 0
# E    +  where 424 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________________________________________________________________________ test_metabolite_annotation_overview[reactome] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 589 metabolites (60.85%) lack annotation for reactome:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 589 == 0
# E    +  where 589 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _____________________________________________________________________________ test_metabolite_annotation_overview[metanetx.chemical] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 167 metabolites (17.25%) lack annotation for
# E     metanetx.chemical:         2mb_p_c, 2mba_c, 2mba_e, 2mpa_c, 2mpa_e,
# E     ...
# E   assert 167 == 0
# E    +  where 167 = len(['2mb_p_c', '2mba_c', '2mba_e', '2mpa_c', '2mpa_e', 'fe3pyovd_kt_e', ...])
# ______________________________________________________________________________ test_metabolite_annotation_overview[bigg.metabolite] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 147 metabolites (15.19%) lack annotation for
# E     bigg.metabolite:         aproa_c, id3acald_c, ind3ac_c, im4act_c,
# E     im4ac_c, ...
# E   assert 147 == 0
# E    +  where 147 = len(['aproa_c', 'id3acald_c', 'ind3ac_c', 'im4act_c', 'im4ac_c', 'imzacd_c', ...])
# ___________________________________________________________________________________ test_metabolite_annotation_overview[biocyc] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 301 metabolites (31.10%) lack annotation for biocyc:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 301 == 0
# E    +  where 301 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# _____________________________________________________________________________________ test_reaction_annotation_overview[rhea] _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 744 reactions (56.49%) lack annotation for rhea:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 744 == 0
# E    +  where 744 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[kegg.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 843 reactions (64.01%) lack annotation for
# E     kegg.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 843 == 0
# E    +  where 843 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[seed.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 450 reactions (34.17%) lack annotation for
# E     seed.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 450 == 0
# E    +  where 450 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ______________________________________________________________________________ test_reaction_annotation_overview[metanetx.reaction] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 224 reactions (17.01%) lack annotation for
# E     metanetx.reaction:         13PPDH2, 2AACLPPEAT160, 2MBAt6, 2MPAt6,
# E     2OBUT_Et, ...
# E   assert 224 == 0
# E    +  where 224 = len(['13PPDH2', '2AACLPPEAT160', '2MBAt6', '2MPAt6', '2OBUT_Et', '4HBAt', ...])
# ________________________________________________________________________________ test_reaction_annotation_overview[bigg.reaction] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 134 reactions (10.17%) lack annotation for
# E     bigg.reaction:         AGPATr_BS, ALATA_D, ALATA_D2, ALATA_L2,
# E     ALCD22_L, ...
# E   assert 134 == 0
# E    +  where 134 = len(['AGPATr_BS', 'ALATA_D', 'ALATA_D2', 'ALATA_L2', 'ALCD22_L', 'CYSK2_I', ...])
# ___________________________________________________________________________________ test_reaction_annotation_overview[reactome] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1132 reactions (85.95%) lack annotation for reactome:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1132 == 0
# E    +  where 1132 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ___________________________________________________________________________________ test_reaction_annotation_overview[ec-code] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 620 reactions (47.08%) lack annotation for ec-code:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 620 == 0
# E    +  where 620 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ____________________________________________________________________________________ test_reaction_annotation_overview[brenda] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1317 reactions (100.00%) lack annotation for brenda:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1317 == 0
# E    +  where 1317 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ____________________________________________________________________________________ test_reaction_annotation_overview[biocyc] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 730 reactions (55.43%) lack annotation for biocyc:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 730 == 0
# E    +  where 730 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# __________________________________________________________________________________ test_gene_product_annotation_overview[refseq] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for refseq:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[uniprot] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for uniprot:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[ecogene] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ecogene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ________________________________________________________________________________ test_gene_product_annotation_overview[kegg.genes] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for kegg.genes:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# __________________________________________________________________________________ test_gene_product_annotation_overview[ncbigi] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigi:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________________________________________________________________________ test_gene_product_annotation_overview[ncbigene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _______________________________________________________________________________ test_gene_product_annotation_overview[ncbiprotein] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for ncbiprotein:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[ccds] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ccds:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[hprd] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for hprd:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ___________________________________________________________________________________ test_gene_product_annotation_overview[asap] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for asap:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _____________________________________________________________________________ test_metabolite_annotation_wrong_ids[pubchem.compound] ______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the pubchem.compound database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _______________________________________________________________________________ test_metabolite_annotation_wrong_ids[seed.compound] _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:292: in test_metabolite_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 1 metabolite annotations (0.14%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     seed.compound         database: trdox_c
# E   assert 1 == 0
# E    +  where 1 = len(['trdox_c'])
# ___________________________________________________________________________________ test_metabolite_annotation_wrong_ids[inchi] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the inchi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ____________________________________________________________________________________ test_reaction_annotation_wrong_ids[rhea] _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 59 reaction annotations (4.48%) do not match the
# E     regular expression patterns defined on identifiers.org for the rhea
# E     database: AEPabcpp, ARGabc, ASPabc, ASPabcpp, CA2abc, ...
# E   assert 59 == 0
# E    +  where 59 = len(['AEPabcpp', 'ARGabc', 'ASPabc', 'ASPabcpp', 'CA2abc', 'CA2abc1', ...])
# ________________________________________________________________________________ test_reaction_annotation_wrong_ids[kegg.reaction] ________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 12 reaction annotations (0.91%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     kegg.reaction         database: AMALT1, AMALT2, AMALT3, HCO3E, LACZpp,
# E     ...
# E   assert 12 == 0
# E    +  where 12 = len(['AMALT1', 'AMALT2', 'AMALT3', 'HCO3E', 'LACZpp', 'MAL6PG', ...])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[ec-code] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 77 reaction annotations (5.85%) do not match the
# E     regular expression patterns defined on identifiers.org for the ec-code
# E     database: 4ABUTD, 4HTHRS, AKGDH, AKGt2r, ALCD4, ...
# E   assert 77 == 0
# E    +  where 77 = len(['4ABUTD', '4HTHRS', 'AKGDH', 'AKGt2r', 'ALCD4', 'ALCD4y', ...])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[brenda] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:328: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the brenda database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________________________________________________________________________ test_reaction_annotation_wrong_ids[biocyc] ____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 5 reaction annotations (0.38%) do not match the
# E     regular expression patterns defined on identifiers.org for the biocyc
# E     database: PHETYRr, TYRALAr, TYRGLUr, TYRTHRr, GLYTYRAP
# E   assert 5 == 0
# E    +  where 5 = len(['PHETYRr', 'TYRALAr', 'TYRGLUr', 'TYRTHRr', 'GLYTYRAP'])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[refseq] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:386: in test_gene_product_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 591 gene annotations (98.34%) do not match the
# E     regular expression patterns defined on identifiers.org for the refseq
# E     database: WP_012290939_1, WP_012290272_1, WP_002842355_1,
# E     WP_012291190_1, WP_012290992_1, ...
# E   assert 591 == 0
# E    +  where 591 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ecogene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ecogene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ncbigi] __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ncbigene] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[ccds] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ccds database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[hprd] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the hprd database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________________________________________________________________________ test_gene_product_annotation_wrong_ids[asap] ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the asap database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ____________________________________________________________________________________ test_gene_protein_reaction_rule_presence _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:206: in test_gene_protein_reaction_rule_presence
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are a total of 305 reactions (23.16%) without GPR:
# E     PAPA181pp, 2AGPE161tipp, NTR3B, BUTCT, SPT_syn, ...
# E   assert 305 == 0
# E    +  where 305 = len(['PAPA181pp', '2AGPE161tipp', 'NTR3B', 'BUTCT', 'SPT_syn', 'DAPDC', ...])
# ______________________________________________________________________________________ test_transport_reaction_gpr_presence _______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:499: in test_transport_reaction_gpr_presence
#     assert ann["metric"] < 0.2, ann["message"]
# E   AssertionError: There are a total of 106 transport reactions (31.27% of all
# E     transport reactions) without GPR:         SELTt, TMAMt, SELt,
# E     PACALDtex, ARBT6Pt, ...
# E   assert 0.31268436578171094 < 0.2
# __________________________________________________________________________________________ test_find_unique_metabolites ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:555: in test_find_unique_metabolites
#     assert len(ann["data"]) < len(model.metabolites), ann["message"]
# E   AssertionError: Not counting the same entities in other compartments, there is a
# E     total of 968 (100.00%) unique metabolites in the model: dad_2_c,
# E     drib_c, dpcoa_e, 5mtr_c, gthrd_e, ...
# E   assert 968 < 968
# E    +  where 968 = len(['dad_2_c', 'drib_c', 'dpcoa_e', '5mtr_c', 'gthrd_e', 'glcn_c', ...])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.metabolites
# _________________________________________________________________________________ test_find_duplicate_metabolites_in_compartments _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:584: in test_find_duplicate_metabolites_in_compartments
#     len(ann["data"]), truncate(ann["data"])))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:170: in truncate
#     return ", ".join(sequence)
# E   TypeError: sequence item 0: expected str instance, tuple found
# ____________________________________________________________________________ test_find_reactions_with_partially_identical_annotations _____________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:624: in test_find_reactions_with_partially_identical_annotations
#     assert total == 0, ann["message"]
# E   AssertionError: Based on annotations there are 137 different groups of overlapping
# E     annotation which corresponds to a total of 312 duplicated reactions in
# E     the model.
# E   assert 312 == 0
# __________________________________________________________________________________________ test_find_duplicate_reactions __________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:660: in test_find_duplicate_reactions
#     {}""".format(num, truncate(duplicates)))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:168: in truncate
#     return ", ".join(sequence[:LIST_SLICE] + ["..."])
# E   TypeError: sequence item 0: expected str instance, tuple found
# ____________________________________________________________________________________ test_find_reactions_with_identical_genes _____________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:692: in test_find_reactions_with_identical_genes
#     assert num_dup == 0, ann["message"]
# E   AssertionError: Based only on equal genes there are 154 different groups of
# E     identical reactions which corresponds to a total of 601
# E     duplicated reactions in the model.
# E   assert 601 == 0
# __________________________________________________________________________________________ test_find_medium_metabolites ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:713: in test_find_medium_metabolites
#     ann["metric"] = len(ann["data"]) / num_ex
# E   TypeError: unsupported operand type(s) for /: 'int' and 'list'
# ________________________________________________________________________________________ test_biomass_consistency[Growth] _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:121: in test_biomass_consistency
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: The component molar mass of the biomass reaction Growth sums up to
# E     1.0300277967729958             which is outside of the 1e-03 margin
# E     from 1 mmol / g[CDW] / h.
# E   assert False
# ________________________________________________________________________________________ test_fast_growth_default[Growth] _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:370: in test_fast_growth_default
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction Growth and when the model is simulated on
# E     the provided default medium the growth rate is *lower* than that
# E     of the fastest bacteria. This is to be expected for             a
# E     majority of organisms.
# E   assert False
# ________________________________________________________________________________ test_essential_precursors_not_in_biomass[Growth] _________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:494: in test_essential_precursors_not_in_biomass
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: Growth lacks a total of 1 essential metabolites         (1.72% of all
# E     biomass precursors). Specifically         these are: ['fmn_c'].
# E   assert 1 == 0
# E    +  where 1 = len(['fmn_c'])
# __________________________________________________________________________________________ test_reaction_charge_balance ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:158: in test_reaction_charge_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 3 (0.26%) reactions are charge unbalanced with at
# E     least one of the metabolites not having a charge or the overall
# E     charge not equal to 0: BTS2, AGPATr_BS, G3POA_BS
# E   assert 3 == 0
# E    +  where 3 = len(['BTS2', 'AGPATr_BS', 'G3POA_BS'])
# ___________________________________________________________________________________________ test_reaction_mass_balance ____________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:193: in test_reaction_mass_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 2 (0.17%) reactions are mass unbalanced with at least
# E     one of the metabolites not having a formula or the overall mass not
# E     equal to 0: AGPATr_BS, G3POA_BS
# E   assert 2 == 0
# E    +  where 2 = len(['AGPATr_BS', 'G3POA_BS'])
# _____________________________________________________________________________________________ test_blocked_reactions ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:222: in test_blocked_reactions
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 98 (7.44%) blocked reactions in         the model: EX_btn_e,
# E     EX_chol_e, EX_rmn_e, EX_spmd_e, EX_xyl__D_e, ...
# E   assert 98 == 0
# E    +  where 98 = len(['EX_btn_e', 'EX_chol_e', 'EX_rmn_e', 'EX_spmd_e', 'EX_xyl__D_e', 'ALDD22x', ...])
# __________________________________________________________________________________ test_find_stoichiometrically_balanced_cycles ___________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:246: in test_find_stoichiometrically_balanced_cycles
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 111 (8.43%) reactions         which participate in SBC in
# E     the model: 13PPDH, 13PPDH2, 4ABUTD, ABUTD, ACCOAL, ...
# E   assert 111 == 0
# E    +  where 111 = len(['13PPDH', '13PPDH2', '4ABUTD', 'ABUTD', 'ACCOAL', 'ACKr', ...])
# ________________________________________________________________________________________________ test_find_orphans ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:271: in test_find_orphans
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 42 (4.34%) metabolites are not produced by any reaction
# E     of the model: cl_p, inost_c, aproa_c, id3acald_c, im4act_c, ...
# E   assert 42 == 0
# E    +  where 42 = len(['cl_p', 'inost_c', 'aproa_c', 'id3acald_c', 'im4act_c', 'imzacd_c', ...])
# _______________________________________________________________________________________________ test_find_deadends ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:295: in test_find_deadends
#     assert ann["data"] == 0, ann["message"]
# E   AssertionError: A total of 45 (4.65%) metabolites are not consumed by any reaction
# E     of the model: 2ins_c, spmd_c, ind3ac_c, im4ac_c, imzac_c, ...
# E   assert ['2ins_c', 'spmd_c', 'ind3ac_c', 'im4ac_c', 'imzac_c', '4aabutn_c', ...] == 0
# _____________________________________________________________________________________________ test_find_disconnected ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:319: in test_find_disconnected
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 5 (0.52%) metabolites are not associated with any
# E     reaction of the model: 3php_c, pa160140_c, pa160180_c, pa160205n3_c,
# E     pa160226n3_c
# E   assert 5 == 0
# E    +  where 5 = len(['3php_c', 'pa160140_c', 'pa160180_c', 'pa160205n3_c', 'pa160226n3_c'])
# _______________________________________________________________________________ test_find_metabolites_not_produced_with_open_bounds _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:349: in test_find_metabolites_not_produced_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 250 (25.83%) metabolites cannot be produced in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 250 == 0
# E    +  where 250 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# _______________________________________________________________________________ test_find_metabolites_not_consumed_with_open_bounds _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:379: in test_find_metabolites_not_consumed_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 255 (26.34%) metabolites cannot be consumed in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 255 == 0
# E    +  where 255 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# ______________________________________________________________________________ test_find_reactions_unbounded_flux_default_condition _______________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:413: in test_find_reactions_unbounded_flux_default_condition
#     assert ann["metric"] <= 0.1, ann["message"]
# E   AssertionError:  A fraction of 22.32% of the non-blocked reactions (in total 98
# E     reactions) can carry unbounded flux in the default model
# E     condition. Unbounded reactions may be involved in
# E     thermodynamically infeasible cycles: 13PPDH, 13PPDH2, 4ABUTD, ABUTD,
# E     ACCOAL, ...
# E   assert 0.22323462414578588 <= 0.1
# _________________________________________________________________________________________________ test_sbml_level _________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:39: in test_sbml_level
#     sbml_version[0], sbml_version[1])
# E   TypeError: 'NoneType' object is not subscriptable
# ________________________________________________________________________________________________ test_fbc_presence ________________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:66: in test_fbc_presence
#     fbc_present = sbml_version[2] is not None
# E   TypeError: 'NoneType' object is not subscriptable
# __________________________________________________________________________________________ test_metabolite_sbo_presence ___________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:58: in test_metabolite_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.metabolites
# ___________________________________________________________________________________________ test_reaction_sbo_presence ____________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:88: in test_reaction_sbo_presence
#     assert len(ann["data"]) == len(model.reactions), ann["message"]
# E   AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 1317
# E    +  where 0 = len([])
# E    +  and   1317 = len([<Reaction 12DGR120tipp at 0x7ff0540d9fa0>, <Reaction 12DGR140tipp at 0x7ff05402e2e0>, <Reaction 12DGR160tipp at 0x7ff...ff045ed5df0>, <Reaction KAS8 at 0x7ff045ed5bb0>, <Reaction NNDPR at 0x7ff045ed5fa0>, <Reaction PPND at 0x7ff045ed5eb0>])
# E    +    where [<Reaction 12DGR120tipp at 0x7ff0540d9fa0>, <Reaction 12DGR140tipp at 0x7ff05402e2e0>, <Reaction 12DGR160tipp at 0x7ff...ff045ed5df0>, <Reaction KAS8 at 0x7ff045ed5bb0>, <Reaction NNDPR at 0x7ff045ed5fa0>, <Reaction PPND at 0x7ff045ed5eb0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.reactions
# _____________________________________________________________________________________________ test_gene_sbo_presence ______________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:117: in test_gene_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# E     SBO term:
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7ff0540d9f70>, <Gene WP_012290272_1 at 0x7ff0541a2d00>, <Gene WP_002842355_1 at 0x7ff0540d9...7ff05402e190>, <Gene FMG_0827 at 0x7ff05402e160>, <Gene FMG_1032 at 0x7ff05402e130>, <Gene FMG_0500 at 0x7ff05402e100>])
# E    +    where [<Gene WP_012290939_1 at 0x7ff0540d9f70>, <Gene WP_012290272_1 at 0x7ff0541a2d00>, <Gene WP_002842355_1 at 0x7ff0540d9...7ff05402e190>, <Gene FMG_0827 at 0x7ff05402e160>, <Gene FMG_1032 at 0x7ff05402e130>, <Gene FMG_0500 at 0x7ff05402e100>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.genes
# __________________________________________________________________________________ test_metabolic_reaction_specific_sbo_presence __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:150: in test_metabolic_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(pure), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all purely
# E     metabolic reactions) lack annotation with the SBO term
# E     "SBO:0000176" for 'biochemical reaction':
# E   assert 0 == 818
# E    +  where 0 = len([])
# E    +  and   818 = len({<Reaction FACOAL170_anteiso at 0x7ff04663adc0>, <Reaction CYTOM at 0x7ff046707fd0>, <Reaction FACOAL170_ISO at 0x7ff0...>, <Reaction CLPNH180pp at 0x7ff04675ffa0>, <Reaction FBP at 0x7ff04663ae20>, <Reaction GDPDPK at 0x7ff0466384c0>, ...})
# __________________________________________________________________________________ test_transport_reaction_specific_sbo_presence __________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:188: in test_transport_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(transports), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# E     reactions) lack annotation with one of the SBO terms: ['SBO:0000185',
# E     'SBO:0000588', 'SBO:0000587', 'SBO:0000655', 'SBO:0000654',
# E     'SBO:0000660', 'SBO:0000659', 'SBO:0000657', 'SBO:0000658'] for
# E     'biochemical reaction':
# E   assert 0 == 339
# E    +  where 0 = len([])
# E    +  and   339 = len({<Reaction SELTt at 0x7ff046238340>, <Reaction DIPEPabc3 at 0x7ff0466d85e0>, <Reaction PA180abcpp at 0x7ff0463a0820>, <Reaction GLCNt2r at 0x7ff046638820>, <Reaction NIabc at 0x7ff046420880>, <Reaction TMAMt at 0x7ff046198a30>, ...})
# ______________________________________________________________________________________ test_metabolite_specific_sbo_presence ______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:218: in test_metabolite_specific_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# E     lack annotation with the SBO term "SBO:0000247" for
# E     'simple chemical':
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>])
# E    +    where [<Metabolite 10fthf_c at 0x7ff0541a2df0>, <Metabolite 12dag3p_BS_c at 0x7ff0541a2e80>, <Metabolite 12dgr120_c at 0x7ff...abolite tyrglu_c at 0x7ff054124790>, <Metabolite tyrthr_c at 0x7ff0541247c0>, <Metabolite gly_tyr_c at 0x7ff0541247f0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.metabolites
# _________________________________________________________________________________________ test_gene_specific_sbo_presence _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:248: in test_gene_specific_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all genes) lack             annotation
# E     with the SBO term "SBO:0000243" for             'gene':
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7ff0540d9f70>, <Gene WP_012290272_1 at 0x7ff0541a2d00>, <Gene WP_002842355_1 at 0x7ff0540d9...7ff05402e190>, <Gene FMG_0827 at 0x7ff05402e160>, <Gene FMG_1032 at 0x7ff05402e130>, <Gene FMG_0500 at 0x7ff05402e100>])
# E    +    where [<Gene WP_012290939_1 at 0x7ff0540d9f70>, <Gene WP_012290272_1 at 0x7ff0541a2d00>, <Gene WP_002842355_1 at 0x7ff0540d9...7ff05402e190>, <Gene FMG_0827 at 0x7ff05402e160>, <Gene FMG_1032 at 0x7ff05402e130>, <Gene FMG_0500 at 0x7ff05402e100>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7ff0542059a0>.genes
# _______________________________________________________________________________________ test_exchange_specific_sbo_presence _______________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:290: in test_exchange_specific_sbo_presence
#     assert len(ann["data"]) == len(exchanges), ann["message"]
# E   AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# E     reactions) lack annotation with the SBO term "SBO:0000627" for
# E     'exchange reaction':
# E   assert 0 == 157
# E    +  where 0 = len([])
# E    +  and   157 = len([<Reaction EX_14glucan_e at 0x7ff0460dafd0>, <Reaction EX_15dap_e at 0x7ff0460da6a0>, <Reaction EX_26dap__M_e at 0x7ff...Reaction EX_atp_e at 0x7ff045f77820>, <Reaction EX_pan4p_e at 0x7ff045f77790>, <Reaction EX_dpcoa_e at 0x7ff045f77df0>])
# _________________________________________________________________________________________ test_sink_specific_sbo_presence _________________________________________________________________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:376: in test_sink_specific_sbo_presence
#     assert len(ann["data"]) == len(sinks), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# E     annotation with the SBO term "SBO:0000632" for         'sink
# E     reaction':
# E   assert 0 == 2
# E    +  where 0 = len([])
# E    +  and   2 = len([<Reaction sink_lipopb_c at 0x7ff0460daf70>, <Reaction sink_mobd_c at 0x7ff0460dac10>])
# ================================================================================================ warnings summary =================================================================================================
# /home/salatan/anaconda3/lib/python3.8/site-packages/_pytest/config/__init__.py:886
#   /home/salatan/anaconda3/lib/python3.8/site-packages/_pytest/config/__init__.py:886: PytestAssertRewriteWarning: Module already imported so cannot be rewritten: anyio
#     self._mark_plugins_for_rewrite(hook)
#
# -- Docs: https://docs.pytest.org/en/latest/warnings.html
# ========================================================================== 77 failed, 49 passed, 19 skipped, 1 warnings in 19.81 seconds ==========================================================================

# %% [markdown]
# ### Clean Up annotations via own python code:

# %%
# Model polishing via ModelPolisher
# cd ModelPolisher
# systemctl start docker
# sudo docker-compose run -v /mnt/Data/Uni/7.Semester/Nextcloud_SysBio_Linux/Josua_Carl_BT/finegoldia_magna_py/2.2:/models/ polisher java -jar /ModelPolisher-2.1-beta.jar --input=/models/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.xml --output=/models/mp-output/finegoldia_magna_ATCC_29328_2.2.mp2.xml  --annotate-with-bigg=true --add-adb-annotations=true --output-combine=true

# %%
# !python annotate_links_from_mp.py "2.2/mp-output2/model.xml" "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.xml" "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.mp2.xml" "finegoldia_magna" "2.2"
# Out:
# 100%|████████████████████████████████████| 14684/14684 [00:25<00:00, 569.91it/s]

# %%
# !python annotate_reactions.py "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.mp2.xml" "2.2/finegoldia_magna_ATCC_29328_2.2.fo.ch.mp.mcb.lt.re.ar.gpr.pw.gf1.gfmm.gf2.gfco3.circ.mcb2.sbo.eco.mp2.re.xml" "2.2/tables/reactions_not_in_bigg_2.tsv" "2.2/memote-reports/annotated_genes_2.html"
# Out:
# 100%|██████████████████████████████████████| 1317/1317 [00:03<00:00, 425.95it/s]
# 100%|███████████████████████████████████████| 1317/1317 [04:44<00:00,  4.62it/s]
# ============================= test session starts ==============================
# platform linux -- Python 3.8.8, pytest-4.6.11, py-1.10.0, pluggy-0.13.1
# rootdir: /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests
# plugins: anyio-3.3.0
# collected 145 items
#
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py . [  0%]
# ..FFFFFFFFFFFFFFFFFFFFFFFFFFFFFFF.F.F......FF....FFFF.F.FF.FFF..         [ 44%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py . [ 45%]
# .....F........F.FFFFFF                                                   [ 60%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py . [ 61%]
# F.....F.F                                                                [ 67%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py . [ 68%]
# ssssssssssssssssFFFFFFFFFF                                               [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_essentiality.py s [ 86%]
#                                                                          [ 86%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_growth.py s [ 87%]
#                                                                          [ 87%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_matrix.py . [ 88%]
# ...                                                                      [ 90%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py F [ 91%]
# F                                                                        [ 91%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py F [ 92%]
# FFFFFFFsF.                                                               [ 99%]
# ../../../../../../../home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_thermodynamics.py . [100%]
#
# =================================== FAILURES ===================================
# ____________ test_metabolite_annotation_overview[pubchem.compound] _____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for
# E     pubchem.compound:         10fthf_c, 12dag3p_BS_c, 12dgr120_c,
# E     12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# ______________ test_metabolite_annotation_overview[kegg.compound] ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 359 metabolites (37.09%) lack annotation for
# E     kegg.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 359 == 0
# E    +  where 359 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ______________ test_metabolite_annotation_overview[seed.compound] ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 248 metabolites (25.62%) lack annotation for
# E     seed.compound:         12dag3p_BS_c, 12dgr120_c, 12dgr120_p,
# E     12dgr140_c, 12dgr140_p, ...
# E   assert 248 == 0
# E    +  where 248 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ________________ test_metabolite_annotation_overview[inchikey] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 295 metabolites (30.48%) lack annotation for inchikey:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 295 == 0
# E    +  where 295 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________ test_metabolite_annotation_overview[inchi] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 968 metabolites (100.00%) lack annotation for inchi:
# E     10fthf_c, 12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, ...
# E   assert 968 == 0
# E    +  where 968 = len(['10fthf_c', '12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', ...])
# __________________ test_metabolite_annotation_overview[chebi] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 315 metabolites (32.54%) lack annotation for chebi:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 315 == 0
# E    +  where 315 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# __________________ test_metabolite_annotation_overview[hmdb] ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 424 metabolites (43.80%) lack annotation for hmdb:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 424 == 0
# E    +  where 424 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ________________ test_metabolite_annotation_overview[reactome] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 589 metabolites (60.85%) lack annotation for reactome:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 589 == 0
# E    +  where 589 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ____________ test_metabolite_annotation_overview[metanetx.chemical] ____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 167 metabolites (17.25%) lack annotation for
# E     metanetx.chemical:         2mb_p_c, 2mba_c, 2mba_e, 2mpa_c, 2mpa_e,
# E     ...
# E   assert 167 == 0
# E    +  where 167 = len(['2mb_p_c', '2mba_c', '2mba_e', '2mpa_c', '2mpa_e', 'fe3pyovd_kt_e', ...])
# _____________ test_metabolite_annotation_overview[bigg.metabolite] _____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 147 metabolites (15.19%) lack annotation for
# E     bigg.metabolite:         aproa_c, id3acald_c, ind3ac_c, im4act_c,
# E     im4ac_c, ...
# E   assert 147 == 0
# E    +  where 147 = len(['aproa_c', 'id3acald_c', 'ind3ac_c', 'im4act_c', 'im4ac_c', 'imzacd_c', ...])
# _________________ test_metabolite_annotation_overview[biocyc] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:153: in test_metabolite_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 301 metabolites (31.10%) lack annotation for biocyc:
# E     12dag3p_BS_c, 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, ...
# E   assert 301 == 0
# E    +  where 301 = len(['12dag3p_BS_c', '12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr160_c', ...])
# ___________________ test_reaction_annotation_overview[rhea] ____________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 737 reactions (55.96%) lack annotation for rhea:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 737 == 0
# E    +  where 737 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# _______________ test_reaction_annotation_overview[kegg.reaction] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 842 reactions (63.93%) lack annotation for
# E     kegg.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 842 == 0
# E    +  where 842 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# _______________ test_reaction_annotation_overview[seed.reaction] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 445 reactions (33.79%) lack annotation for
# E     seed.reaction:         12DGR120tipp, 12DGR140tipp, 12DGR160tipp,
# E     12DGR161tipp, 12DGR180tipp, ...
# E   assert 445 == 0
# E    +  where 445 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# _____________ test_reaction_annotation_overview[metanetx.reaction] _____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 196 reactions (14.88%) lack annotation for
# E     metanetx.reaction:         13PPDH2, 2AACLPPEAT160, 2MBAt6, 2MPAt6,
# E     2OBUT_Et, ...
# E   assert 196 == 0
# E    +  where 196 = len(['13PPDH2', '2AACLPPEAT160', '2MBAt6', '2MPAt6', '2OBUT_Et', '4HBAt', ...])
# _______________ test_reaction_annotation_overview[bigg.reaction] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 134 reactions (10.17%) lack annotation for
# E     bigg.reaction:         AGPATr_BS, ALATA_D, ALATA_D2, ALATA_L2,
# E     ALCD22_L, ...
# E   assert 134 == 0
# E    +  where 134 = len(['AGPATr_BS', 'ALATA_D', 'ALATA_D2', 'ALATA_L2', 'ALCD22_L', 'CYSK2_I', ...])
# _________________ test_reaction_annotation_overview[reactome] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1129 reactions (85.73%) lack annotation for reactome:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1129 == 0
# E    +  where 1129 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# __________________ test_reaction_annotation_overview[ec-code] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 619 reactions (47.00%) lack annotation for ec-code:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 619 == 0
# E    +  where 619 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# __________________ test_reaction_annotation_overview[brenda] ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 1317 reactions (100.00%) lack annotation for brenda:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 1317 == 0
# E    +  where 1317 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# __________________ test_reaction_annotation_overview[biocyc] ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:199: in test_reaction_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 726 reactions (55.13%) lack annotation for biocyc:
# E     12DGR120tipp, 12DGR140tipp, 12DGR160tipp, 12DGR161tipp, 12DGR180tipp,
# E     ...
# E   assert 726 == 0
# E    +  where 726 = len(['12DGR120tipp', '12DGR140tipp', '12DGR160tipp', '12DGR161tipp', '12DGR180tipp', '12DGR181tipp', ...])
# ________________ test_gene_product_annotation_overview[refseq] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for refseq:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# ________________ test_gene_product_annotation_overview[uniprot] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for uniprot:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# ________________ test_gene_product_annotation_overview[ecogene] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ecogene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ______________ test_gene_product_annotation_overview[kegg.genes] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 10 genes (1.66%) lack annotation for kegg.genes:
# E     spontaneous, WP_002838602_1, WP_012290557_1, FMG_RS06010, FMG_1297,
# E     ...
# E   assert 10 == 0
# E    +  where 10 = len(['spontaneous', 'WP_002838602_1', 'WP_012290557_1', 'FMG_RS06010', 'FMG_1297', 'FMG_0667', ...])
# ________________ test_gene_product_annotation_overview[ncbigi] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigi:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _______________ test_gene_product_annotation_overview[ncbigene] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ncbigene:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ______________ test_gene_product_annotation_overview[ncbiprotein] ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 217 genes (36.11%) lack annotation for ncbiprotein:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290371_1, ...
# E   assert 217 == 0
# E    +  where 217 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290371_1', 'spontaneous', ...])
# _________________ test_gene_product_annotation_overview[ccds] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for ccds:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________ test_gene_product_annotation_overview[hprd] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for hprd:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _________________ test_gene_product_annotation_overview[asap] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:245: in test_gene_product_annotation_overview
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: The following 601 genes (100.00%) lack annotation for asap:
# E     WP_012290939_1, WP_012290272_1, WP_002842355_1, WP_012291190_1,
# E     WP_012290992_1, ...
# E   assert 601 == 0
# E    +  where 601 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# ____________ test_metabolite_annotation_wrong_ids[pubchem.compound] ____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the pubchem.compound database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _____________ test_metabolite_annotation_wrong_ids[seed.compound] ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:292: in test_metabolite_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 1 metabolite annotations (0.14%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     seed.compound         database: trdox_c
# E   assert 1 == 0
# E    +  where 1 = len(['trdox_c'])
# _________________ test_metabolite_annotation_wrong_ids[inchi] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:281: in test_metabolite_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no metabolite annotations for the inchi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________ test_reaction_annotation_wrong_ids[rhea] ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 59 reaction annotations (4.48%) do not match the
# E     regular expression patterns defined on identifiers.org for the rhea
# E     database: AEPabcpp, ARGabc, ASPabc, ASPabcpp, CA2abc, ...
# E   assert 59 == 0
# E    +  where 59 = len(['AEPabcpp', 'ARGabc', 'ASPabc', 'ASPabcpp', 'CA2abc', 'CA2abc1', ...])
# ______________ test_reaction_annotation_wrong_ids[kegg.reaction] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 12 reaction annotations (0.91%) do not match the
# E     regular expression patterns defined on identifiers.org for the
# E     kegg.reaction         database: AMALT1, AMALT2, AMALT3, HCO3E, LACZpp,
# E     ...
# E   assert 12 == 0
# E    +  where 12 = len(['AMALT1', 'AMALT2', 'AMALT3', 'HCO3E', 'LACZpp', 'MAL6PG', ...])
# _________________ test_reaction_annotation_wrong_ids[ec-code] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 79 reaction annotations (6.00%) do not match the
# E     regular expression patterns defined on identifiers.org for the ec-code
# E     database: 4ABUTD, 4HTHRS, AKGDH, AKGt2r, ALCD4, ...
# E   assert 79 == 0
# E    +  where 79 = len(['4ABUTD', '4HTHRS', 'AKGDH', 'AKGt2r', 'ALCD4', 'ALCD4y', ...])
# __________________ test_reaction_annotation_wrong_ids[brenda] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:328: in test_reaction_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no reaction annotations for the brenda database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# __________________ test_reaction_annotation_wrong_ids[biocyc] __________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:339: in test_reaction_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 5 reaction annotations (0.38%) do not match the
# E     regular expression patterns defined on identifiers.org for the biocyc
# E     database: PHETYRr, TYRALAr, TYRGLUr, TYRTHRr, GLYTYRAP
# E   assert 5 == 0
# E    +  where 5 = len(['PHETYRr', 'TYRALAr', 'TYRGLUr', 'TYRTHRr', 'GLYTYRAP'])
# ________________ test_gene_product_annotation_wrong_ids[refseq] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:386: in test_gene_product_annotation_wrong_ids
#     assert len(ann["data"][db]) == 0, ann["message"][db]
# E   AssertionError: A total of 591 gene annotations (98.34%) do not match the
# E     regular expression patterns defined on identifiers.org for the refseq
# E     database: WP_012290939_1, WP_012290272_1, WP_002842355_1,
# E     WP_012291190_1, WP_012290992_1, ...
# E   assert 591 == 0
# E    +  where 591 = len(['WP_012290939_1', 'WP_012290272_1', 'WP_002842355_1', 'WP_012291190_1', 'WP_012290992_1', 'WP_012290328_1', ...])
# _______________ test_gene_product_annotation_wrong_ids[ecogene] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ecogene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ________________ test_gene_product_annotation_wrong_ids[ncbigi] ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigi database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _______________ test_gene_product_annotation_wrong_ids[ncbigene] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ncbigene database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_gene_product_annotation_wrong_ids[ccds] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the ccds database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_gene_product_annotation_wrong_ids[hprd] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the hprd database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# _________________ test_gene_product_annotation_wrong_ids[asap] _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_annotation.py:375: in test_gene_product_annotation_wrong_ids
#     assert len(total) > 0, ann["message"][db]
# E   AssertionError: There are no gene annotations for the asap database.
# E   assert 0 > 0
# E    +  where 0 = len([])
# ___________________ test_gene_protein_reaction_rule_presence ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:206: in test_gene_protein_reaction_rule_presence
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are a total of 305 reactions (23.16%) without GPR:         ATPM,
# E     NMNP, SBTPD, PAPA160pp, PPND, ...
# E   assert 305 == 0
# E    +  where 305 = len(['ATPM', 'NMNP', 'SBTPD', 'PAPA160pp', 'PPND', 'Ktex', ...])
# _____________________ test_transport_reaction_gpr_presence _____________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:499: in test_transport_reaction_gpr_presence
#     assert ann["metric"] < 0.2, ann["message"]
# E   AssertionError: There are a total of 106 transport reactions (31.27% of all
# E     transport reactions) without GPR:         MALTHXtexi, 12DGR120tipp,
# E     4PEPTtex, DDCAt2pp, MNtex, ...
# E   assert 0.31268436578171094 < 0.2
# _________________________ test_find_unique_metabolites _________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:555: in test_find_unique_metabolites
#     assert len(ann["data"]) < len(model.metabolites), ann["message"]
# E   AssertionError: Not counting the same entities in other compartments, there is a
# E     total of 968 (100.00%) unique metabolites in the model:
# E     ala_L_asp__L_e, fa3_c, lald__L_c, mg2_c, murein3p3p_p, ...
# E   assert 968 < 968
# E    +  where 968 = len(['ala_L_asp__L_e', 'fa3_c', 'lald__L_c', 'mg2_c', 'murein3p3p_p', 'gly_pro__L_e', ...])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>])
# E    +    where [<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.metabolites
# _______________ test_find_duplicate_metabolites_in_compartments ________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:584: in test_find_duplicate_metabolites_in_compartments
#     len(ann["data"]), truncate(ann["data"])))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:170: in truncate
#     return ", ".join(sequence)
# E   TypeError: sequence item 0: expected str instance, tuple found
# ___________ test_find_reactions_with_partially_identical_annotations ___________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:624: in test_find_reactions_with_partially_identical_annotations
#     assert total == 0, ann["message"]
# E   AssertionError: Based on annotations there are 139 different groups of overlapping
# E     annotation which corresponds to a total of 317 duplicated reactions in
# E     the model.
# E   assert 317 == 0
# ________________________ test_find_duplicate_reactions _________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:660: in test_find_duplicate_reactions
#     {}""".format(num, truncate(duplicates)))
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/utils.py:168: in truncate
#     return ", ".join(sequence[:LIST_SLICE] + ["..."])
# E   TypeError: sequence item 0: expected str instance, tuple found
# ___________________ test_find_reactions_with_identical_genes ___________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:692: in test_find_reactions_with_identical_genes
#     assert num_dup == 0, ann["message"]
# E   AssertionError: Based only on equal genes there are 154 different groups of
# E     identical reactions which corresponds to a total of 601
# E     duplicated reactions in the model.
# E   assert 601 == 0
# _________________________ test_find_medium_metabolites _________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_basic.py:713: in test_find_medium_metabolites
#     ann["metric"] = len(ann["data"]) / num_ex
# E   TypeError: unsupported operand type(s) for /: 'int' and 'list'
# _______________________ test_biomass_consistency[Growth] _______________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:121: in test_biomass_consistency
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: The component molar mass of the biomass reaction Growth sums up to
# E     1.0300277967729958             which is outside of the 1e-03 margin
# E     from 1 mmol / g[CDW] / h.
# E   assert False
# _______________________ test_fast_growth_default[Growth] _______________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:370: in test_fast_growth_default
#     assert outcome, ann["message"][reaction_id]
# E   AssertionError: Using the biomass reaction Growth and when the model is simulated on
# E     the provided default medium the growth rate is *lower* than that
# E     of the fastest bacteria. This is to be expected for             a
# E     majority of organisms.
# E   assert False
# _______________ test_essential_precursors_not_in_biomass[Growth] _______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_biomass.py:494: in test_essential_precursors_not_in_biomass
#     assert len(ann["data"][reaction_id]) == 0, ann["message"][reaction_id]
# E   AssertionError: Growth lacks a total of 1 essential metabolites         (1.72% of all
# E     biomass precursors). Specifically         these are: ['fmn_c'].
# E   assert 1 == 0
# E    +  where 1 = len(['fmn_c'])
# _________________________ test_reaction_charge_balance _________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:158: in test_reaction_charge_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 3 (0.26%) reactions are charge unbalanced with at
# E     least one of the metabolites not having a charge or the overall
# E     charge not equal to 0: BTS2, G3POA_BS, AGPATr_BS
# E   assert 3 == 0
# E    +  where 3 = len(['BTS2', 'G3POA_BS', 'AGPATr_BS'])
# __________________________ test_reaction_mass_balance __________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:193: in test_reaction_mass_balance
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 2 (0.17%) reactions are mass unbalanced with at least
# E     one of the metabolites not having a formula or the overall mass not
# E     equal to 0: G3POA_BS, AGPATr_BS
# E   assert 2 == 0
# E    +  where 2 = len(['G3POA_BS', 'AGPATr_BS'])
# ____________________________ test_blocked_reactions ____________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:222: in test_blocked_reactions
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 98 (7.44%) blocked reactions in         the model: EX_btn_e,
# E     EX_chol_e, EX_rmn_e, EX_spmd_e, EX_xyl__D_e, ...
# E   assert 98 == 0
# E    +  where 98 = len(['EX_btn_e', 'EX_chol_e', 'EX_rmn_e', 'EX_spmd_e', 'EX_xyl__D_e', 'ALDD22x', ...])
# _________________ test_find_stoichiometrically_balanced_cycles _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:246: in test_find_stoichiometrically_balanced_cycles
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: There are 111 (8.43%) reactions         which participate in SBC in
# E     the model: 13PPDH, 13PPDH2, 4ABUTD, ABUTD, ACCOAL, ...
# E   assert 111 == 0
# E    +  where 111 = len(['13PPDH', '13PPDH2', '4ABUTD', 'ABUTD', 'ACCOAL', 'ACKr', ...])
# ______________________________ test_find_orphans _______________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:271: in test_find_orphans
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 42 (4.34%) metabolites are not produced by any reaction
# E     of the model: cl_p, inost_c, aproa_c, id3acald_c, im4act_c, ...
# E   assert 42 == 0
# E    +  where 42 = len(['cl_p', 'inost_c', 'aproa_c', 'id3acald_c', 'im4act_c', 'imzacd_c', ...])
# ______________________________ test_find_deadends ______________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:295: in test_find_deadends
#     assert ann["data"] == 0, ann["message"]
# E   AssertionError: A total of 45 (4.65%) metabolites are not consumed by any reaction
# E     of the model: 2ins_c, spmd_c, ind3ac_c, im4ac_c, imzac_c, ...
# E   assert ['2ins_c', 'spmd_c', 'ind3ac_c', 'im4ac_c', 'imzac_c', '4aabutn_c', ...] == 0
# ____________________________ test_find_disconnected ____________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:319: in test_find_disconnected
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 5 (0.52%) metabolites are not associated with any
# E     reaction of the model: 3php_c, pa160140_c, pa160180_c, pa160205n3_c,
# E     pa160226n3_c
# E   assert 5 == 0
# E    +  where 5 = len(['3php_c', 'pa160140_c', 'pa160180_c', 'pa160205n3_c', 'pa160226n3_c'])
# _____________ test_find_metabolites_not_produced_with_open_bounds ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:349: in test_find_metabolites_not_produced_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 250 (25.83%) metabolites cannot be produced in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 250 == 0
# E    +  where 250 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# _____________ test_find_metabolites_not_consumed_with_open_bounds ______________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:379: in test_find_metabolites_not_consumed_with_open_bounds
#     assert len(ann["data"]) == 0, ann["message"]
# E   AssertionError: A total of 255 (26.34%) metabolites cannot be consumed in complete
# E     medium: 12dgr120_c, 12dgr120_p, 12dgr140_c, 12dgr140_p, 12dgr161_c,
# E     ...
# E   assert 255 == 0
# E    +  where 255 = len(['12dgr120_c', '12dgr120_p', '12dgr140_c', '12dgr140_p', '12dgr161_c', '12dgr161_p', ...])
# _____________ test_find_reactions_unbounded_flux_default_condition _____________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_consistency.py:413: in test_find_reactions_unbounded_flux_default_condition
#     assert ann["metric"] <= 0.1, ann["message"]
# E   AssertionError:  A fraction of 22.32% of the non-blocked reactions (in total 98
# E     reactions) can carry unbounded flux in the default model
# E     condition. Unbounded reactions may be involved in
# E     thermodynamically infeasible cycles: 13PPDH, 13PPDH2, 4ABUTD, ABUTD,
# E     ACCOAL, ...
# E   assert 0.22323462414578588 <= 0.1
# _______________________________ test_sbml_level ________________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:39: in test_sbml_level
#     sbml_version[0], sbml_version[1])
# E   TypeError: 'NoneType' object is not subscriptable
# ______________________________ test_fbc_presence _______________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbml.py:66: in test_fbc_presence
#     fbc_present = sbml_version[2] is not None
# E   TypeError: 'NoneType' object is not subscriptable
# _________________________ test_metabolite_sbo_presence _________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:58: in test_metabolite_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 metabolites (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>])
# E    +    where [<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.metabolites
# __________________________ test_reaction_sbo_presence __________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:88: in test_reaction_sbo_presence
#     assert len(ann["data"]) == len(model.reactions), ann["message"]
# E   AssertionError: A total of 0 reactions (0.00%) lack annotation with any type
# E     of SBO term:
# E   assert 0 == 1317
# E    +  where 0 = len([])
# E    +  and   1317 = len([<Reaction 12DGR120tipp at 0x7fd9caa08580>, <Reaction 12DGR140tipp at 0x7fd9c7cc18b0>, <Reaction 12DGR160tipp at 0x7fd...fd9c7bf8eb0>, <Reaction KAS8 at 0x7fd9cac6feb0>, <Reaction NNDPR at 0x7fd9cac6fcd0>, <Reaction PPND at 0x7fd9cac6fa90>])
# E    +    where [<Reaction 12DGR120tipp at 0x7fd9caa08580>, <Reaction 12DGR140tipp at 0x7fd9c7cc18b0>, <Reaction 12DGR160tipp at 0x7fd...fd9c7bf8eb0>, <Reaction KAS8 at 0x7fd9cac6feb0>, <Reaction NNDPR at 0x7fd9cac6fcd0>, <Reaction PPND at 0x7fd9cac6fa90>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.reactions
# ____________________________ test_gene_sbo_presence ____________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:117: in test_gene_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00%) lack annotation with any type of
# E     SBO term:
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7fd9caa08550>, <Gene WP_012290272_1 at 0x7fd9caa085e0>, <Gene WP_002842355_1 at 0x7fd9caa08...7fd9c7cc11c0>, <Gene FMG_0827 at 0x7fd9c7cc1190>, <Gene FMG_1032 at 0x7fd9c7cc1130>, <Gene FMG_0500 at 0x7fd9c7cc10d0>])
# E    +    where [<Gene WP_012290939_1 at 0x7fd9caa08550>, <Gene WP_012290272_1 at 0x7fd9caa085e0>, <Gene WP_002842355_1 at 0x7fd9caa08...7fd9c7cc11c0>, <Gene FMG_0827 at 0x7fd9c7cc1190>, <Gene FMG_1032 at 0x7fd9c7cc1130>, <Gene FMG_0500 at 0x7fd9c7cc10d0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.genes
# ________________ test_metabolic_reaction_specific_sbo_presence _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:150: in test_metabolic_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(pure), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all purely
# E     metabolic reactions) lack annotation with the SBO term
# E     "SBO:0000176" for 'biochemical reaction':
# E   assert 0 == 818
# E    +  where 0 = len([])
# E    +  and   818 = len({<Reaction MDDEP4pp at 0x7fd9c7d180d0>, <Reaction MCTP2App at 0x7fd9c7d18340>, <Reaction ACGAMPM at 0x7fd9c7ce8370>, <Reaction 2AGPEAT180 at 0x7fd9c7cf4eb0>, <Reaction TDPDRR at 0x7fd9c7fa0400>, <Reaction NTPP10 at 0x7fd9c7ef4ee0>, ...})
# ________________ test_transport_reaction_specific_sbo_presence _________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:188: in test_transport_reaction_specific_sbo_presence
#     assert len(ann["data"]) == len(transports), ann["message"]
# E   AssertionError: A total of 0 metabolic reactions (0.00% of all transport
# E     reactions) lack annotation with one of the SBO terms: ['SBO:0000185',
# E     'SBO:0000588', 'SBO:0000587', 'SBO:0000655', 'SBO:0000654',
# E     'SBO:0000660', 'SBO:0000659', 'SBO:0000657', 'SBO:0000658'] for
# E     'biochemical reaction':
# E   assert 0 == 339
# E    +  where 0 = len([])
# E    +  and   339 = len({<Reaction GLCptspp at 0x7fd9c80e8070>, <Reaction MALTabc at 0x7fd9c7d10370>, <Reaction TYRabc at 0x7fd9c7b203d0>, <Re...n MALTHXtexi at 0x7fd9c7d104f0>, <Reaction 12DGR120tipp at 0x7fd9caa08580>, <Reaction ACTNabc1 at 0x7fd9c7d185b0>, ...})
# ____________________ test_metabolite_specific_sbo_presence _____________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:218: in test_metabolite_specific_sbo_presence
#     assert len(ann["data"]) == len(model.metabolites), ann["message"]
# E   AssertionError: A total of 0 transport reactions (0.00% of all metabolites)
# E     lack annotation with the SBO term "SBO:0000247" for
# E     'simple chemical':
# E   assert 0 == 968
# E    +  where 0 = len([])
# E    +  and   968 = len([<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>])
# E    +    where [<Metabolite 10fthf_c at 0x7fd9ca261700>, <Metabolite 12dag3p_BS_c at 0x7fd9ca261f70>, <Metabolite 12dgr120_c at 0x7fd...abolite tyrglu_c at 0x7fd9ca9e8ac0>, <Metabolite tyrthr_c at 0x7fd9ca9e8b20>, <Metabolite gly_tyr_c at 0x7fd9ca9e8b80>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.metabolites
# _______________________ test_gene_specific_sbo_presence ________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:248: in test_gene_specific_sbo_presence
#     assert len(ann["data"]) == len(model.genes), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all genes) lack             annotation
# E     with the SBO term "SBO:0000243" for             'gene':
# E   assert 0 == 601
# E    +  where 0 = len([])
# E    +  and   601 = len([<Gene WP_012290939_1 at 0x7fd9caa08550>, <Gene WP_012290272_1 at 0x7fd9caa085e0>, <Gene WP_002842355_1 at 0x7fd9caa08...7fd9c7cc11c0>, <Gene FMG_0827 at 0x7fd9c7cc1190>, <Gene FMG_1032 at 0x7fd9c7cc1130>, <Gene FMG_0500 at 0x7fd9c7cc10d0>])
# E    +    where [<Gene WP_012290939_1 at 0x7fd9caa08550>, <Gene WP_012290272_1 at 0x7fd9caa085e0>, <Gene WP_002842355_1 at 0x7fd9caa08...7fd9c7cc11c0>, <Gene FMG_0827 at 0x7fd9c7cc1190>, <Gene FMG_1032 at 0x7fd9c7cc1130>, <Gene FMG_0500 at 0x7fd9c7cc10d0>] = <Model finegoldia_magna_ATCC_29328_2_2_raw at 0x7fd9ca2cde50>.genes
# _____________________ test_exchange_specific_sbo_presence ______________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:290: in test_exchange_specific_sbo_presence
#     assert len(ann["data"]) == len(exchanges), ann["message"]
# E   AssertionError: A total of 0 exchange reactions (0.00% of all exchange
# E     reactions) lack annotation with the SBO term "SBO:0000627" for
# E     'exchange reaction':
# E   assert 0 == 157
# E    +  where 0 = len([])
# E    +  and   157 = len([<Reaction EX_14glucan_e at 0x7fd9c8391940>, <Reaction EX_15dap_e at 0x7fd9c8391370>, <Reaction EX_26dap__M_e at 0x7fd...Reaction EX_atp_e at 0x7fd9c7ab9e50>, <Reaction EX_pan4p_e at 0x7fd9c7ab9e80>, <Reaction EX_dpcoa_e at 0x7fd9c7ab9c10>])
# _______________________ test_sink_specific_sbo_presence ________________________
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/suite/tests/test_sbo.py:376: in test_sink_specific_sbo_presence
#     assert len(ann["data"]) == len(sinks), ann["message"]
# E   AssertionError: A total of 0 genes (0.00% of all sink reactions) lack
# E     annotation with the SBO term "SBO:0000632" for         'sink
# E     reaction':
# E   assert 0 == 2
# E    +  where 0 = len([])
# E    +  and   2 = len([<Reaction sink_lipopb_c at 0x7fd9c8391d90>, <Reaction sink_mobd_c at 0x7fd9c804cd90>])
# =============================== warnings summary ===============================
# /home/salatan/anaconda3/lib/python3.8/site-packages/memote/support/thermodynamics.py:23
#   /home/salatan/anaconda3/lib/python3.8/site-packages/memote/support/thermodynamics.py:23: DeprecationWarning: Using or importing the ABCs from 'collections' instead of from 'collections.abc' is deprecated since Python 3.3, and in 3.9 it will stop working
#     from collections import Iterable, defaultdict
#
# -- Docs: https://docs.pytest.org/en/latest/warnings.html
# ======== 77 failed, 49 passed, 19 skipped, 1 warnings in 22.92 seconds =========
